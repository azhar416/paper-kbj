# %%
# import library
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import plotly.express as px 
from datetime import datetime
import os
from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
# tabel setting
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
pd.set_option('display.precision', 2)
pd.options.display.float_format = '{:,.2f}'.format

# %%
dataset_dir = '../../Dataset/Revisi 4/'

# %%
df = pd.read_csv(dataset_dir + 'sensor3_clean.csv')

# %%
df['Label'].value_counts()
# Out:
# Label
# 0    3253459
# 1      39953
# 2       9946
# Name: count, dtype: int64

# %% [markdown]
# # Split

# %%
def split_data(df):
    train, test = train_test_split(df, test_size=0.25, random_state=42, stratify=df['Label'])
    return train, test

# %%
df_train, df_test = split_data(df)

# %%
df_train.to_csv(dataset_dir + 'sensor3_train.csv', index=False)
df_test.to_csv(dataset_dir + 'sensor3_test.csv', index=False)
